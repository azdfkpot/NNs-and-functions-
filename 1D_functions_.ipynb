# %% [markdown]
# <a href="https://colab.research.google.com/github/azdfkpot/NNs-and-functions-/blob/main/1D_functions_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense

# Define the neural network architecture
model = Sequential()
model.add(Dense(50, input_dim=1, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1))

# Prepare the data for training
x_train = np.linspace(2, 10, 1000).reshape(-1, 1)
y_train = np.cos(2*x_train) + x_train*np.sin(3*x_train) + np.sqrt(x_train)

# Train the neural network
model.compile(loss='mse', optimizer='adam')
model.fit(x_train, y_train, epochs=300, batch_size=32)

# Evaluate the trained neural network
x_test = np.linspace(2, 10, 1000).reshape(-1, 1)
y_test = np.cos(2*x_test) + x_test*np.sin(3*x_test) + np.sqrt(x_test)
y_pred = model.predict(x_test)

# Plot the exact curve and the neural network curve
plt.plot(x_test, y_test, label='The curve of f')
plt.plot(x_test, y_pred, label='Neural network approximation ')
plt.legend()
plt.show()
# Out:
# Epoch 1/300
# 32/32 [==============================] - 2s 8ms/step - loss: 25.3929
# Epoch 2/300
# 32/32 [==============================] - 0s 12ms/step - loss: 22.3447
# Epoch 3/300
# 32/32 [==============================] - 0s 13ms/step - loss: 22.3487
# Epoch 4/300
# 32/32 [==============================] - 0s 5ms/step - loss: 22.3077
# Epoch 5/300
# 32/32 [==============================] - 0s 13ms/step - loss: 22.3075
# Epoch 6/300
# 32/32 [==============================] - 0s 11ms/step - loss: 22.2454
# Epoch 7/300
# 32/32 [==============================] - 0s 9ms/step - loss: 22.2917
# Epoch 8/300
# 32/32 [==============================] - 0s 13ms/step - loss: 22.2989
# Epoch 9/300
# 32/32 [==============================] - 0s 8ms/step - loss: 22.3396
# Epoch 10/300
# 32/32 [==============================] - 0s 13ms/step - loss: 22.2767
# Epoch 11/300
# 32/32 [==============================] - 0s 13ms/step - loss: 22.2117
# Epoch 12/300
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense

# Define the neural network architecture
model = Sequential()
model.add(Dense(50, input_dim=1, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1))

# Prepare the data for training
x_train = np.linspace(2, 10, 1000).reshape(-1, 1)
y_train = np.cos(2*x_train) + x_train*np.sin(3*x_train) + np.sqrt(x_train)

# Train the neural network
model.compile(loss='mse', optimizer='adam')
model.fit(x_train, y_train, epochs=500, batch_size=32)

# Evaluate the trained neural network
x_test = np.linspace(2, 10, 1000).reshape(-1, 1)
y_test = np.cos(2*x_test) + x_test*np.sin(3*x_test) + np.sqrt(x_test)
y_pred = model.predict(x_test)

# Plot the exact curve and the neural network curve
plt.plot(x_test, y_test, label='The curve of f')
plt.plot(x_test, y_pred, label='Neural network approximation ')
plt.legend()
plt.show()
# Out:
# Epoch 1/500
# 32/32 [==============================] - 1s 2ms/step - loss: 22.7364
# Epoch 2/500
# 32/32 [==============================] - 0s 2ms/step - loss: 22.4103
# Epoch 3/500
# 32/32 [==============================] - 0s 2ms/step - loss: 22.3670
# Epoch 4/500
# 32/32 [==============================] - 0s 2ms/step - loss: 22.3618
# Epoch 5/500
# 32/32 [==============================] - 0s 2ms/step - loss: 22.3549
# Epoch 6/500
# 32/32 [==============================] - 0s 2ms/step - loss: 22.3081
# Epoch 7/500
# 32/32 [==============================] - 0s 2ms/step - loss: 22.4146
# Epoch 8/500
# 32/32 [==============================] - 0s 2ms/step - loss: 22.3012
# Epoch 9/500
# 32/32 [==============================] - 0s 2ms/step - loss: 22.2702
# Epoch 10/500
# 32/32 [==============================] - 0s 2ms/step - loss: 22.2322
# Epoch 11/500
# 32/32 [==============================] - 0s 2ms/step - loss: 22.3407
# Epoch 12/500
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense

# Define the neural network architecture
model = Sequential()
model.add(Dense(100, input_dim=1, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(1))

# Prepare the data for training
x_train = np.linspace(2, 10, 1000).reshape(-1, 1)
y_train = np.cos(2*x_train) + x_train*np.sin(3*x_train) + np.sqrt(x_train)

# Train the neural network
model.compile(loss='mse', optimizer='adam')
model.fit(x_train, y_train, epochs=1000, batch_size=32)

# Evaluate the trained neural network
x_test = np.linspace(2, 10, 1000).reshape(-1, 1)
y_test = np.cos(2*x_test) + x_test*np.sin(3*x_test) + np.sqrt(x_test)
y_pred = model.predict(x_test)

# Plot the exact curve and the neural network curve
plt.plot(x_test, y_test, label='The curve of f')
plt.plot(x_test, y_pred, label='Neural network approximation ')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# 32/32 [==============================] - 2s 2ms/step - loss: 23.0615
# Epoch 2/1000
# 32/32 [==============================] - 0s 2ms/step - loss: 22.5059
# Epoch 3/1000
# 32/32 [==============================] - 0s 2ms/step - loss: 22.4524
# Epoch 4/1000
# 32/32 [==============================] - 0s 2ms/step - loss: 22.4398
# Epoch 5/1000
# 32/32 [==============================] - 0s 2ms/step - loss: 22.3128
# Epoch 6/1000
# 32/32 [==============================] - 0s 2ms/step - loss: 22.2940
# Epoch 7/1000
# 32/32 [==============================] - 0s 2ms/step - loss: 22.3391
# Epoch 8/1000
# 32/32 [==============================] - 0s 2ms/step - loss: 22.3457
# Epoch 9/1000
# 32/32 [==============================] - 0s 2ms/step - loss: 22.2903
# Epoch 10/1000
# 32/32 [==============================] - 0s 2ms/step - loss: 22.2931
# Epoch 11/1000
# 32/32 [==============================] - 0s 2ms/step - loss: 22.1636
# Epoch 12/1000
# ...
